# %% [markdown]
# # DESCARGA Y CÁLCULO DEL SENTIMIENTO DE NOTICIAS DEL DIARIO EL TIEMPO
#
# Este notebook describe el paso a paso que permitirá calcular el sentimiento de las noticias publicadas en el diario [El Tiempo](https://www.eltiempo.com)

# %% [markdown]
# ### Paso 1: Instalación de software necesario
#
# --- Python
#
# Puede obtenerse instalando [Anaconda](https://www.anaconda.com). Para ello, ingrese [aquí](https://www.anaconda.com/products/distribution), descargue el instalador y ejecútelo.
#
# --- Git
#
# Ingrese [aquí](https://git-scm.com/downloads), descargue el instalador y ejecútelo.

# %% [markdown]
# ### Paso 2: Instalación de dependencias
#
# Para ello, ejecute la siguiente celda

# %%
# !pip install scrapy==2.6.1
# !pip install pyodbc==4.0.32
# !pip install nltk==3.6.5
# !pip install textblob==0.17.1
# !pip install transformers==4.17.0
# !pip install pysftp==0.2.9
# !pip install ipywidgets==7.6.5
# !pip install deep-translator==1.8.3
# !pip install sentiment-analysis-spanish==0.0.25
# !pip install pysentimiento==0.3.2

# %% [markdown]
# ### Paso 2.1: Carga de librerías necesarias
#
# Para ello, ejecute la siguiente celda

# %%
import os
import shutil
from IPython.display import clear_output
import pandas as pd
from toolbox import get_date_inputs, clean_news, translate_news, upload_to_lz, save_local

from pysentimiento import create_analyzer
from sentiment_analysis_spanish import sentiment_analysis
import nltk

from nltk.sentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from transformers import BertTokenizer, BertForSequenceClassification, pipeline

nltk.download([
  "names",
  "stopwords",
  "state_union",
  "twitter_samples",
  "movie_reviews",
  "averaged_perceptron_tagger",
  "vader_lexicon",
  "punkt",
])

clear_output(wait = True)

analyzer = create_analyzer(task="sentiment", lang="es")
sentiment = sentiment_analysis.SentimentAnalysisSpanish()
sia = SentimentIntensityAnalyzer()
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-tone', num_labels = 3)
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-tone')
nlp = pipeline("sentiment-analysis", model = finbert, tokenizer = tokenizer)

clear_output(wait = False)
print('LIBRERÍAS IMPORTADAS CORRECTAMENTE')

# %% [markdown]
# ### Paso 3: Descarga de la última versión del código fuente (código que permitirá la descarga de las noticias)
#
# Para ello, es necesario ejecutar la siguiente celda

# %%
# !if exist eltiempo_news_scraper (rmdir /s /q eltiempo_news_scraper)

REPOSITORY_URL = 'http://sbmdeqpc04/data-extraction-dasolano/eltiempo_news_scraper'

# !git clone $REPOSITORY_URL
clear_output(wait = True)

# !if exist eltiempo_news_scraper (echo 'LA ULTIMA VERSION DEL CODIGO FUE DESCARGADA EXITOSAMENTE') else (echo '¡ERROR!: EL CODIGO NO PUDO SER DESCARGADO. REVISE CONEXION Y VPN')

# %% [markdown]
# ### Paso 4: Descarga de las noticias de interés
#
# Las noticias se pueden filtrar por:

# %% [markdown]
# * *Términos de busqueda*
#
# Inmediatamente después de la siguiente celda usted tendrá la oportunidad de ingresar los términos sobre los cuales quiere buscar noticias. Cada vez que le aparezca
# un campo para ingresar texto escriba el término de interés y presione la tecla *enter*. Por favor no escriba palabras que no agregan significado; por ejemplo, en vez de escribir "Banco de la República" escriba "Banco República", o en vez de "Grupo de Energía de Bogotá" escriba "Grupo Energía Bogotá". Si ya escribió todos los términos de interés, en vez de escribir uno adicional presione la tecla *enter*.
# En caso de que quiera buscar todas las noticias (es decir, todas y absolutamente todas las que el programa encuentre), simplemente presione la tecla *enter* cuando le aparezca por primera vez el campo de texto.

# %%
SEARCH_TERMS = []

while True:
  search_term = input('Ingrese el término de búsqueda o presione la tecla ENTER para terminar\n').strip().upper()
  if not search_term:
    break
  SEARCH_TERMS.append(search_term)

print('Términos de búsqueda:', SEARCH_TERMS if SEARCH_TERMS else 'TODAS LAS NOTICIAS')

# %% [markdown]
# * *Fechas inicial y final*
#
# De la misma manera, inmediatamente después de siguiente celda debe indicar el periodo en el que se quieren buscar noticias. Para ello, ingrese el mes (por ejemplo: "Febrero") y el año (por ejemplo: 2021) inicial y el mes y el año final.

# %%
start_month, start_year, end_month, end_year = get_date_inputs()
START_DATE = f'{start_year}-{start_month}'
END_DATE = f'{end_year}-{end_month}'

# %%
SEARCH_TERMS = ['GRUPO ARGOS', 'BANCO BOGOTA', 'BANCOLOMBIA', 'CEMENTOS ARGOS', 'CELSIA', 'CORFICOLOMBIANA', 'DAVIVIENDA', 'ECOPETROL', 'GRUPO AVAL', 'GRUPO ENERGIA BOGOTA', 'ISA', 'NUTRESA', 'GRUPO SURA']
start_month, start_year, end_month, end_year = 1, 2010, 5, 2022

# %%
# !if exist news (rmdir /s /q news)
SEARCH_TERMS_STR = ','.join(SEARCH_TERMS)
current_year = int(start_year)
end_year = int(end_year)

while current_year <= end_year:
  current_start_date = f'{current_year}-{start_month if current_year == int(start_year) else "01"}'
  current_end_date = f'{current_year}-{12 if current_year < end_year else end_month}'
  # !cd eltiempo_news_scraper && scrapy crawl news -a search_terms="$SEARCH_TERMS_STR" -a start_date=$current_start_date -a end_date=$current_end_date -o ..\news\news-"$current_year".csv
  clear_output(wait = True)
  current_year += 1

clear_output(wait = False)
# !if exist news (echo 'NOTICIAS DESCARGADAS CON EXITO') else (echo '¡ERROR!: ALGO OCURRIO, INTENTE NUEVAMENTE ')

# %% [markdown]
# ### Paso 5: Limpieza de texto y filtrado de las noticias
#
# Las noticias obtenidas tienen algunos caracteres y textos no deseados. Adicionalmente, algunos resultados están duplicados, así como otros que no coinciden con el término de busqueda empleado en ésta. Para limpiar el texto y filtrar las noticias, ejecute la celda inferior.

# %%
for current_year in range(int(start_year), int(end_year) + 1):
  current_news = pd.read_csv(f'news/news-{current_year}.csv')
  current_news = current_news.astype(str)
  
  news_cleaned = clean_news(current_news)
  # !del news\news-"$current_year".csv
  news_cleaned.to_csv(f'news/news-{current_year}.csv', index = False)
  print(f'NOTICIAS DEL AÑO {current_year} FUERON LIMPIADAS Y FILTRADAS')

print('*' * 50)
print('LIMPIEZA Y FILTRADO CONCLUYERON EXITOSAMENTE')
# Out:
# NOTICIAS DEL AÑO 2010 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2011 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2012 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2013 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2014 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2015 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2016 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2017 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2018 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2019 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2020 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2021 FUERON LIMPIADAS Y FILTRADAS
# NOTICIAS DEL AÑO 2022 FUERON LIMPIADAS Y FILTRADAS
# **************************************************
# LIMPIEZA Y FILTRADO CONCLUYERON EXITOSAMENTE

# %% [markdown]
# ### Paso 5.1 (OPCIONAL): Persistencia de las noticias (destino: local)
# Las noticias serán guardadas en el mismo directorio de este notebook como **ALL_NEWS.csv**

# %%
save_local('news', 'ALL_NEWS')
# Out:
# LAS NOTICIAS FUERON GUARDADAS EXITOSAMENTE COMO ALL_NEWS.csv

# %% [markdown]
# ### Paso 5.2 (OPCIONAL): Persistencia de las noticias (destino: nube)
# En caso de querer subir información a la nube se debe utilizar el método **upload_to_lz()**, en donde *database* es el nombre de la base de datos a la cual usted esté autorizado y *table_name* el nombre con el que la tabla quedará cargada en la nube. Tenga en cuenta que en el mismo directorio de este notebook debe existir un archivo llamado **credentials.json**, debe contener lo siguiente: **{ "user": "su_usuario", "password": "su_contraseña", "server": "sbmdeblze004" }**

# %%
save_local('news', 'ALL_NEWS')
all_news = pd.read_csv('ALL_NEWS.csv')
all_news = all_news.astype(str)

database = 'proceso'
table_name = 'dasolano_eltiempo_news'

upload_to_lz(dataframe = all_news, database = database, table_name = table_name)
clear_output(wait = True)
# !del ALL_NEWS.csv
print(f'LAS NOTICIAS HAN SIDO CARGADAS A LA NUBE EXITOSAMENTE. UBICACIÓN LZ: {database}.{table_name}')

# %% [markdown]
# ### Paso 6: Cálculo del sentimiento en español (título, subtítulo y contenido)
#
# Se calcula el sentimiento del título, subtitulo y contenido de cada noticia usando las librerías [pysentimiento](https://github.com/pysentimiento/pysentimiento)
# y [sentiment-spanish](https://github.com/sentiment-analysis-spanish/sentiment-spanish)

# %%
if os.path.exists('news_sentiment_spanish'):
  if os.listdir('news_sentiment_spanish'):
    # !rmdir /s /q news_sentiment_spanish
    # !mkdir news_sentiment_spanish
else:
  # !mkdir news_sentiment_spanish

for current_year in range(int(start_year), int(end_year) + 1):

  news_spanish = pd.read_csv(f'news/news-{current_year}.csv')
  news_spanish = news_spanish.astype(str)

  news_title_sentiment = news_spanish['news_title'].apply(lambda title: analyzer.predict(title).probas)
  news_subtitle_sentiment = news_spanish['news_subtitle'].apply(lambda subtitle: analyzer.predict(subtitle).probas)
  news_content_sentiment = news_spanish['news_text_content'].apply(lambda content: analyzer.predict(content).probas)

  news_spanish['news_title_prob_POS_pysent'] = news_title_sentiment.apply(lambda sentiment: sentiment['POS'])
  news_spanish['news_title_prob_NEU_pysent'] = news_title_sentiment.apply(lambda sentiment: sentiment['NEU'])
  news_spanish['news_title_prob_NEG_pysent'] = news_title_sentiment.apply(lambda sentiment: sentiment['NEG'])

  news_spanish['news_subtitle_prob_POS_pysent'] = news_subtitle_sentiment.apply(lambda sentiment: sentiment['POS'])
  news_spanish['news_subtitle_prob_NEU_pysent'] = news_subtitle_sentiment.apply(lambda sentiment: sentiment['NEU'])
  news_spanish['news_subtitle_prob_NEG_pysent'] = news_subtitle_sentiment.apply(lambda sentiment: sentiment['NEG'])

  news_spanish['news_text_content_prob_POS_pysent'] = news_content_sentiment.apply(lambda sentiment: sentiment['POS'])
  news_spanish['news_text_content_prob_NEU_pysent'] = news_content_sentiment.apply(lambda sentiment: sentiment['NEU'])
  news_spanish['news_text_content_prob_NEG_pysent'] = news_content_sentiment.apply(lambda sentiment: sentiment['NEG'])

  news_spanish['news_title_sent_sentspanish'] = news_spanish['news_title'].apply(lambda title: sentiment.sentiment(title))
  news_spanish['news_subtitle_sent_sentspanish'] = news_spanish['news_subtitle'].apply(lambda subtitle: sentiment.sentiment(subtitle))
  news_spanish['news_text_content_sent_sentspanish'] = news_spanish['news_text_content'].apply(lambda content: sentiment.sentiment(content))

  news_spanish.to_csv(f'news_sentiment_spanish/news_sentiment_spanish-{current_year}.csv', index = False)
  
  print(f'CALCULO DE SENTIMIENTO (ESPAÑOL) DE NOTICIAS DEL AÑO {current_year} REALIZADO EXITOSAMENTE')

print('*' * 80)
print('CALCULO DE SENTIMIENTO (ESPAÑOL) REALIZADO EXITOSAMENTE')

# %% [markdown]
# ### Paso 6.1 (OPCIONAL): Persistencia de las noticias en español con sentimiento (destino: local)
# Las noticias serán guardadas en el mismo directorio de este notebook como **ALL_NEWS_SENTIMENT.csv**

# %%
save_local('news_sentiment_spanish', 'ALL_NEWS_SENTIMENT')

# %% [markdown]
# ### Paso 6.2 (OPCIONAL): Persistencia de las noticias en español con sentimiento (destino: nube)
# En caso de querer subir información a la nube se debe utilizar el método **upload_to_lz()**, en donde *database* es el nombre de la base de datos a la cual usted esté autorizado y *table_name* el nombre con el que la tabla quedará cargada en la nube. Tenga en cuenta que en el mismo directorio de este notebook debe existir un archivo llamado **credentials.json**, debe contener lo siguiente: **{ "user": "su_usuario", "password": "su_contraseña", "server": "sbmdeblze004" }**

# %%
save_local('news_sentiment_spanish', 'ALL_NEWS_SENTIMENT')
all_news = pd.read_csv('ALL_NEWS_SENTIMENT.csv')
all_news = all_news.astype(str)

database = 'proceso'
table_name = 'dasolano_eltiempo_news_sentiment'

upload_to_lz(dataframe = all_news, database = database, table_name = table_name)
clear_output(wait = True)
# !del ALL_NEWS_SENTIMENT.csv
print(f'LAS NOTICIAS HAN SIDO CARGADAS A LA NUBE EXITOSAMENTE. UBICACIÓN LZ: {database}.{table_name}')

# %% [markdown]
# ### Paso 7: Cálculo del sentimiento en español (título, subtítulo y contenido unidos)
#
# Se calcula el sentimiento de la unión (concatenación) del título, subtitulo y contenido de cada noticia usando las librerías [pysentimiento](https://github.com/pysentimiento/pysentimiento)
# y [sentiment-spanish](https://github.com/sentiment-analysis-spanish/sentiment-spanish). El resultado se guardará en un archivo (en el mismo directorio de este notebook) llamado **news_sentiment_spanish_joined.csv**. Para ello, ejecute la siguiente celda

# %%
if os.path.exists('news_sentiment_spanish_joined'):
  if os.listdir('news_sentiment_spanish_joined'):
    # !rmdir /s /q news_sentiment_spanish_joined
    # !mkdir news_sentiment_spanish_joined
else:
  # !mkdir news_sentiment_spanish_joined
  
for current_year in range(int(start_year), int(end_year) + 1):

  news_spanish = pd.read_csv(f'news/news-{current_year}.csv')
  news_spanish = news_spanish.astype(str)

  news_spanish['news_joined'] = news_spanish['news_title'] + '. ' + news_spanish['news_subtitle'] + '. ' + news_spanish['news_text_content']

  del news_spanish['news_title']
  del news_spanish['news_subtitle']
  del news_spanish['news_text_content']

  news_spanish_joined = news_spanish['news_joined'].apply(lambda news: analyzer.predict(news).probas)

  news_spanish['news_joined_prob_POS_pysent'] = news_spanish_joined.apply(lambda sentiment: sentiment['POS'])
  news_spanish['news_joined_prob_NEU_pysent'] = news_spanish_joined.apply(lambda sentiment: sentiment['NEU'])
  news_spanish['news_joined_prob_NEG_pysent'] = news_spanish_joined.apply(lambda sentiment: sentiment['NEG'])

  news_spanish['news_joined_sent_sentspanish'] = news_spanish['news_joined'].apply(lambda joined_text: sentiment.sentiment(joined_text))

  news_spanish.to_csv(f'news_sentiment_spanish_joined/news_sentiment_spanish_joined-{current_year}.csv', index = False)

  print(f'CALCULO DE SENTIMIENTO (ESPAÑOL) DE NOTICIAS DEL AÑO {current_year} REALIZADO EXITOSAMENTE')

print('*' * 80)
print('CALCULO DE SENTIMIENTO (ESPAÑOL) REALIZADO EXITOSAMENTE')

# %% [markdown]
# ### Paso 7.1 (OPCIONAL): Persistencia de las noticias en español con sentimiento titulo + subtitulo + contenido (destino: local)
# Las noticias serán guardadas en el mismo directorio de este notebook como **ALL_NEWS_SENTIMENT_JOINED.csv**

# %%
save_local('news_sentiment_spanish_joined', 'ALL_NEWS_SENTIMENT_JOINED')

# %% [markdown]
# ### Paso 7.2 (OPCIONAL): Persistencia de las noticias en español con sentimiento titulo + subtitulo + contenido (destino: nube)
# En caso de querer subir información a la nube se debe utilizar el método **upload_to_lz()**, en donde *database* es el nombre de la base de datos a la cual usted esté autorizado y *table_name* el nombre con el que la tabla quedará cargada en la nube. Tenga en cuenta que en el mismo directorio de este notebook debe existir un archivo llamado **credentials.json**, debe contener lo siguiente: **{ "user": "su_usuario", "password": "su_contraseña", "server": "sbmdeblze004" }**

# %%
save_local('news_sentiment_spanish_joined', 'ALL_NEWS_SENTIMENT_JOINED')
all_news = pd.read_csv('ALL_NEWS_SENTIMENT_JOINED.csv')
all_news = all_news.astype(str)

database = 'proceso'
table_name = 'dasolano_eltiempo_news_sentiment_joined'

upload_to_lz(dataframe = all_news, database = database, table_name = table_name)
clear_output(wait = True)
# !del ALL_NEWS_SENTIMENT_JOINED.csv
print(f'LAS NOTICIAS HAN SIDO CARGADAS A LA NUBE EXITOSAMENTE. UBICACIÓN LZ: {database}.{table_name}')

# %% [markdown]
# ### Paso 8: Traducción a inglés de las noticias
#
# Traducción a inglés de las noticias usando la librería [deep-translator](https://github.com/nidhaloff/deep-translator). El resultado se guardará en un archivo (en el mismo directorio de este notebook) llamado **search_results_cleaned_english.csv**. Para ello, ejecute la siguiente celda

# %%
if os.path.exists('news_english'):
  if os.listdir('news_english'):
    # !rmdir /s /q news_english
    # !mkdir news_english
else:
  # !mkdir news_english

for current_year in range(int(start_year), int(end_year) + 1):
  news_spanish = pd.read_csv(f'news/news-{current_year}.csv')
  news_spanish = news_spanish.astype(str)

  news_location = f'news_english/news_english-{current_year}'

  news_english = translate_news(news_spanish, news_location)
  news_english.to_csv(f'{news_location}.csv', index = False)
  shutil.rmtree(news_location)
# Out:
# news_english/news_english-2010-0
# news_english/news_english-2010-1
# news_english/news_english-2010-2
# news_english/news_english-2010-3
# news_english/news_english-2010-4
# news_english/news_english-2010-5
# news_english/news_english-2010-6
# news_english/news_english-2010-7
# news_english/news_english-2010-8
# news_english/news_english-2010-9
# news_english/news_english-2010-10
# news_english/news_english-2010-11
# news_english/news_english-2010-12
# news_english/news_english-2010-13
# news_english/news_english-2010-14
# news_english/news_english-2010-15
# news_english/news_english-2010-16
# news_english/news_english-2010-17
# news_english/news_english-2010-18
# news_english/news_english-2010-19
# news_english/news_english-2010-20
# news_english/news_english-2010-21
# news_english/news_english-2010-22
# news_english/news_english-2010-23
# news_english/news_english-2010-24
# news_english/news_english-2010-25
# news_english/news_english-2010-26
# news_english/news_english-2010-27
# news_english/news_english-2010-28
# news_english/news_english-2010-29
# news_english/news_english-2010-30
# news_english/news_english-2010-31
# news_english/news_english-2010-32
# news_english/news_english-2010-33
# news_english/news_english-2010-34
# news_english/news_english-2010-35
# news_english/news_english-2010-36
# news_english/news_english-2010-37
# news_english/news_english-2010-38
# news_english/news_english-2010-39
# news_english/news_english-2010-40
# news_english/news_english-2010-41
# news_english/news_english-2010-42
# news_english/news_english-2010-43
# news_english/news_english-2010-44
# news_english/news_english-2010-45
# news_english/news_english-2010-46
# news_english/news_english-2010-47
# news_english/news_english-2010-48
# news_english/news_english-2010-49
# news_english/news_english-2010-50
# news_english/news_english-2010-51
# news_english/news_english-2010-52
# news_english/news_english-2010-53
# news_english/news_english-2010-54
# news_english/news_english-2010-55
# news_english/news_english-2010-56
# news_english/news_english-2010-57
# news_english/news_english-2010-58
# news_english/news_english-2010-59
# news_english/news_english-2010-60
# news_english/news_english-2010-61
# news_english/news_english-2010-62
# news_english/news_english-2010-63
# news_english/news_english-2010-64
# news_english/news_english-2010-65
# news_english/news_english-2010-66
# news_english/news_english-2010-67
# news_english/news_english-2010-68
# news_english/news_english-2010-69
# news_english/news_english-2010-70
# news_english/news_english-2010-71
# news_english/news_english-2010-72
# news_english/news_english-2010-73
# news_english/news_english-2010-74
# news_english/news_english-2010-75
# news_english/news_english-2010-76
# news_english/news_english-2010-77
# news_english/news_english-2010-78
# news_english/news_english-2010-79
# news_english/news_english-2010-80
# news_english/news_english-2010-81
# news_english/news_english-2010-82
# news_english/news_english-2010-83
# news_english/news_english-2010-84
# news_english/news_english-2010-85
# news_english/news_english-2010-86
# news_english/news_english-2010-87
# news_english/news_english-2010-88
# news_english/news_english-2010-89
# news_english/news_english-2010-90
# news_english/news_english-2010-91
# news_english/news_english-2010-92
# news_english/news_english-2010-93
# news_english/news_english-2010-94
# news_english/news_english-2010-95
# news_english/news_english-2010-96
# news_english/news_english-2010-97
# news_english/news_english-2010-98
# news_english/news_english-2010-99
# news_english/news_english-2010-100
# news_english/news_english-2010-101
# news_english/news_english-2010-102
# news_english/news_english-2010-103
# news_english/news_english-2010-104
# news_english/news_english-2010-105
# news_english/news_english-2010-106
# news_english/news_english-2010-107
# news_english/news_english-2010-108
# news_english/news_english-2010-109
# news_english/news_english-2010-110
# news_english/news_english-2010-111
# news_english/news_english-2010-112
# news_english/news_english-2010-113
# news_english/news_english-2010-114
# news_english/news_english-2010-115
# news_english/news_english-2010-116
# news_english/news_english-2010-117
# news_english/news_english-2010-118
# news_english/news_english-2010-119
# news_english/news_english-2010-120
# news_english/news_english-2010-121
# news_english/news_english-2010-122
# news_english/news_english-2010-123
# news_english/news_english-2010-124
# news_english/news_english-2010-125
# news_english/news_english-2010-126
# news_english/news_english-2010-127
# news_english/news_english-2010-128
# news_english/news_english-2010-129
# news_english/news_english-2010-130
# news_english/news_english-2010-131
# news_english/news_english-2010-132
# news_english/news_english-2010-133
# news_english/news_english-2010-134
# news_english/news_english-2010-135
# news_english/news_english-2010-136
# news_english/news_english-2010-137
# news_english/news_english-2010-138
# news_english/news_english-2010-139
# news_english/news_english-2010-140
# news_english/news_english-2010-141
# news_english/news_english-2010-142
# news_english/news_english-2010-143
# news_english/news_english-2010-144
# news_english/news_english-2010-145
# news_english/news_english-2010-146
# news_english/news_english-2010-147
# news_english/news_english-2010-148
# news_english/news_english-2010-149
# news_english/news_english-2010-150
# news_english/news_english-2010-151
# news_english/news_english-2010-152
# news_english/news_english-2010-153
# news_english/news_english-2010-154
# news_english/news_english-2010-155
# news_english/news_english-2010-156
# news_english/news_english-2010-157
# news_english/news_english-2010-158
# news_english/news_english-2010-159
# news_english/news_english-2010-160
# news_english/news_english-2010-161
# news_english/news_english-2010-162
# news_english/news_english-2010-163
# news_english/news_english-2010-164
# news_english/news_english-2010-165
# news_english/news_english-2010-166
# news_english/news_english-2010-167
# news_english/news_english-2010-168
# news_english/news_english-2010-169
# news_english/news_english-2010-170
# news_english/news_english-2010-171
# news_english/news_english-2010-172
# news_english/news_english-2010-173
# news_english/news_english-2010-174
# news_english/news_english-2010-175
# news_english/news_english-2010-176
# news_english/news_english-2010-177
# news_english/news_english-2010-178
# news_english/news_english-2010-179
# news_english/news_english-2010-180
# news_english/news_english-2010-181
# news_english/news_english-2010-182
# news_english/news_english-2010-183
# news_english/news_english-2010-184
# news_english/news_english-2010-185
# news_english/news_english-2010-186
# news_english/news_english-2010-187
# news_english/news_english-2010-188
# news_english/news_english-2010-189
# news_english/news_english-2010-190
# news_english/news_english-2010-191
# news_english/news_english-2010-192
# news_english/news_english-2010-193
# news_english/news_english-2010-194
# news_english/news_english-2010-195
# news_english/news_english-2010-196
# news_english/news_english-2010-197
# news_english/news_english-2010-198
# news_english/news_english-2010-199
# news_english/news_english-2010-200
# news_english/news_english-2010-201
# news_english/news_english-2010-202
# news_english/news_english-2010-203
# news_english/news_english-2010-204
# news_english/news_english-2010-205
# news_english/news_english-2010-206
# news_english/news_english-2010-207
# news_english/news_english-2010-208
# news_english/news_english-2010-209
# news_english/news_english-2010-210
# news_english/news_english-2010-211
# news_english/news_english-2010-212
# news_english/news_english-2010-213
# news_english/news_english-2010-214
# news_english/news_english-2010-215
# news_english/news_english-2010-216
# news_english/news_english-2010-217
# news_english/news_english-2010-218
# news_english/news_english-2010-219
# news_english/news_english-2010-220
# news_english/news_english-2010-221
# news_english/news_english-2010-222
# news_english/news_english-2010-223
# news_english/news_english-2010-224
# news_english/news_english-2010-225
# news_english/news_english-2010-226
# news_english/news_english-2010-227
# news_english/news_english-2010-228
# news_english/news_english-2010-229
# news_english/news_english-2010-230
# news_english/news_english-2010-231
# news_english/news_english-2010-232
# news_english/news_english-2010-233
# news_english/news_english-2010-234
# news_english/news_english-2010-235
# news_english/news_english-2010-236
# news_english/news_english-2010-237
# news_english/news_english-2010-238
# news_english/news_english-2010-239
# news_english/news_english-2010-240
# news_english/news_english-2010-241
# news_english/news_english-2010-242
# news_english/news_english-2010-243
# news_english/news_english-2010-244
# news_english/news_english-2010-245
# news_english/news_english-2010-246
# news_english/news_english-2010-247
# news_english/news_english-2010-248
# news_english/news_english-2010-249
# news_english/news_english-2010-250
# news_english/news_english-2010-251
# news_english/news_english-2010-252
# news_english/news_english-2010-253
# news_english/news_english-2010-254
# news_english/news_english-2010-255
# news_english/news_english-2010-256
# news_english/news_english-2010-257
# news_english/news_english-2010-258
# news_english/news_english-2010-259
# news_english/news_english-2010-260
# news_english/news_english-2010-261
# news_english/news_english-2010-262
# news_english/news_english-2010-263
# news_english/news_english-2010-264
# news_english/news_english-2010-265
# news_english/news_english-2010-266
# news_english/news_english-2010-267
# news_english/news_english-2010-268
# news_english/news_english-2010-269
# news_english/news_english-2010-270
# news_english/news_english-2010-271
# news_english/news_english-2010-272
# news_english/news_english-2010-273
# news_english/news_english-2010-274
# news_english/news_english-2010-275
# news_english/news_english-2010-276
# news_english/news_english-2010-277
# news_english/news_english-2010-278
# news_english/news_english-2010-279
# news_english/news_english-2010-280
# news_english/news_english-2010-281
# news_english/news_english-2010-282
# news_english/news_english-2010-283
# news_english/news_english-2010-284
# news_english/news_english-2010-285
# news_english/news_english-2010-286
# news_english/news_english-2010-287
# news_english/news_english-2010-288
# news_english/news_english-2010-289
# news_english/news_english-2010-290
# news_english/news_english-2010-291
# news_english/news_english-2010-292
# news_english/news_english-2010-293
# news_english/news_english-2010-294
# news_english/news_english-2010-295
# news_english/news_english-2010-296
# news_english/news_english-2010-297
# news_english/news_english-2010-298
# news_english/news_english-2010-299
# news_english/news_english-2010-300
# news_english/news_english-2010-301
# news_english/news_english-2010-302
# news_english/news_english-2010-303
# news_english/news_english-2010-304
# news_english/news_english-2010-305
# news_english/news_english-2010-306
# news_english/news_english-2010-307
# news_english/news_english-2010-308
# news_english/news_english-2010-309
# news_english/news_english-2010-310
# news_english/news_english-2010-311
# news_english/news_english-2010-312
# news_english/news_english-2010-313
# news_english/news_english-2010-314
# news_english/news_english-2010-315
# news_english/news_english-2011-0
# news_english/news_english-2011-1
# news_english/news_english-2011-2
# news_english/news_english-2011-3
# news_english/news_english-2011-4
# news_english/news_english-2011-5
# news_english/news_english-2011-6
# news_english/news_english-2011-7
# news_english/news_english-2011-8
# news_english/news_english-2011-9
# news_english/news_english-2011-10
# news_english/news_english-2011-11
# news_english/news_english-2011-12
# news_english/news_english-2011-13
# news_english/news_english-2011-14
# news_english/news_english-2011-15
# news_english/news_english-2011-16
# news_english/news_english-2011-17
# news_english/news_english-2011-18
# news_english/news_english-2011-19
# news_english/news_english-2011-20
# news_english/news_english-2011-21
# news_english/news_english-2011-22
# news_english/news_english-2011-23
# news_english/news_english-2011-24
# news_english/news_english-2011-25
# news_english/news_english-2011-26
# news_english/news_english-2011-27
# news_english/news_english-2011-28
# news_english/news_english-2011-29
# news_english/news_english-2011-30
# news_english/news_english-2011-31
# news_english/news_english-2011-32
# news_english/news_english-2011-33
# news_english/news_english-2011-34
# news_english/news_english-2011-35
# news_english/news_english-2011-36
# news_english/news_english-2011-37
# news_english/news_english-2011-38
# news_english/news_english-2011-39
# news_english/news_english-2011-40
# news_english/news_english-2011-41
# news_english/news_english-2011-42
# news_english/news_english-2011-43
# news_english/news_english-2011-44
# news_english/news_english-2011-45
# news_english/news_english-2011-46
# news_english/news_english-2011-47
# news_english/news_english-2011-48
# news_english/news_english-2011-49
# news_english/news_english-2011-50
# news_english/news_english-2011-51
# news_english/news_english-2011-52
# news_english/news_english-2011-53
# news_english/news_english-2011-54
# news_english/news_english-2011-55
# news_english/news_english-2011-56
# news_english/news_english-2011-57
# news_english/news_english-2011-58
# news_english/news_english-2011-59
# news_english/news_english-2011-60
# news_english/news_english-2011-61
# news_english/news_english-2011-62
# news_english/news_english-2011-63
# news_english/news_english-2011-64
# news_english/news_english-2011-65
# news_english/news_english-2011-66
# news_english/news_english-2011-67
# news_english/news_english-2011-68
# news_english/news_english-2011-69
# news_english/news_english-2011-70
# news_english/news_english-2011-71
# news_english/news_english-2011-72
# news_english/news_english-2011-73
# news_english/news_english-2011-74
# news_english/news_english-2011-75
# news_english/news_english-2011-76
# news_english/news_english-2011-77
# news_english/news_english-2011-78
# news_english/news_english-2011-79
# news_english/news_english-2011-80
# news_english/news_english-2011-81
# news_english/news_english-2011-82
# news_english/news_english-2011-83
# news_english/news_english-2011-84
# news_english/news_english-2011-85
# news_english/news_english-2011-86
# news_english/news_english-2011-87
# news_english/news_english-2011-88
# news_english/news_english-2011-89
# news_english/news_english-2011-90
# news_english/news_english-2011-91
# news_english/news_english-2011-92
# news_english/news_english-2011-93
# news_english/news_english-2011-94
# news_english/news_english-2011-95
# news_english/news_english-2011-96
# news_english/news_english-2011-97
# news_english/news_english-2011-98
# news_english/news_english-2011-99
# news_english/news_english-2011-100
# news_english/news_english-2011-101
# news_english/news_english-2011-102
# news_english/news_english-2011-103
# news_english/news_english-2011-104
# news_english/news_english-2011-105
# news_english/news_english-2011-106
# news_english/news_english-2011-107
# news_english/news_english-2011-108
# news_english/news_english-2011-109
# news_english/news_english-2011-110
# news_english/news_english-2011-111
# news_english/news_english-2011-112
# news_english/news_english-2011-113
# news_english/news_english-2011-114
# news_english/news_english-2011-115
# news_english/news_english-2011-116
# news_english/news_english-2011-117
# news_english/news_english-2011-118
# news_english/news_english-2011-119
# news_english/news_english-2011-120
# news_english/news_english-2011-121
# news_english/news_english-2011-122
# news_english/news_english-2011-123
# news_english/news_english-2011-124
# news_english/news_english-2011-125
# news_english/news_english-2011-126
# news_english/news_english-2011-127
# news_english/news_english-2011-128
# news_english/news_english-2011-129
# news_english/news_english-2011-130
# news_english/news_english-2011-131
# news_english/news_english-2011-132
# news_english/news_english-2011-133
# news_english/news_english-2011-134
# news_english/news_english-2011-135
# news_english/news_english-2011-136
# news_english/news_english-2011-137
# news_english/news_english-2011-138
# news_english/news_english-2011-139
# news_english/news_english-2011-140
# news_english/news_english-2011-141
# news_english/news_english-2011-142
# news_english/news_english-2011-143
# news_english/news_english-2011-144
# news_english/news_english-2011-145
# news_english/news_english-2011-146
# news_english/news_english-2011-147
# news_english/news_english-2011-148
# news_english/news_english-2011-149
# news_english/news_english-2011-150
# news_english/news_english-2011-151
# news_english/news_english-2011-152
# news_english/news_english-2011-153
# news_english/news_english-2011-154
# news_english/news_english-2011-155
# news_english/news_english-2011-156
# news_english/news_english-2011-157
# news_english/news_english-2011-158
# news_english/news_english-2011-159
# news_english/news_english-2011-160
# news_english/news_english-2011-161
# news_english/news_english-2011-162
# news_english/news_english-2011-163
# news_english/news_english-2011-164
# news_english/news_english-2011-165
# news_english/news_english-2011-166
# news_english/news_english-2011-167
# news_english/news_english-2011-168
# news_english/news_english-2011-169
# news_english/news_english-2011-170
# news_english/news_english-2011-171
# news_english/news_english-2011-172
# news_english/news_english-2011-173
# news_english/news_english-2011-174
# news_english/news_english-2011-175
# news_english/news_english-2011-176
# news_english/news_english-2011-177
# news_english/news_english-2011-178
# news_english/news_english-2011-179
# news_english/news_english-2011-180
# news_english/news_english-2011-181
# news_english/news_english-2011-182
# news_english/news_english-2011-183
# news_english/news_english-2011-184
# news_english/news_english-2011-185
# news_english/news_english-2011-186
# news_english/news_english-2011-187
# news_english/news_english-2011-188
# news_english/news_english-2011-189
# news_english/news_english-2011-190
# news_english/news_english-2011-191
# news_english/news_english-2011-192
# news_english/news_english-2011-193
# news_english/news_english-2011-194
# news_english/news_english-2011-195
# news_english/news_english-2011-196
# news_english/news_english-2011-197
# news_english/news_english-2011-198
# news_english/news_english-2011-199
# news_english/news_english-2011-200
# news_english/news_english-2011-201
# news_english/news_english-2011-202
# news_english/news_english-2011-203
# news_english/news_english-2011-204
# news_english/news_english-2011-205
# news_english/news_english-2011-206
# news_english/news_english-2011-207
# news_english/news_english-2011-208
# news_english/news_english-2011-209
# news_english/news_english-2011-210
# news_english/news_english-2011-211
# news_english/news_english-2011-212
# news_english/news_english-2011-213
# news_english/news_english-2011-214
# news_english/news_english-2011-215
# news_english/news_english-2011-216
# news_english/news_english-2011-217
# news_english/news_english-2011-218
# news_english/news_english-2011-219
# news_english/news_english-2011-220
# news_english/news_english-2011-221
# news_english/news_english-2011-222
# news_english/news_english-2011-223
# news_english/news_english-2011-224
# news_english/news_english-2011-225
# news_english/news_english-2011-226
# news_english/news_english-2011-227
# news_english/news_english-2011-228
# news_english/news_english-2011-229
# news_english/news_english-2011-230
# news_english/news_english-2011-231
# news_english/news_english-2011-232
# news_english/news_english-2011-233
# news_english/news_english-2011-234
# news_english/news_english-2011-235
# news_english/news_english-2011-236
# news_english/news_english-2011-237
# news_english/news_english-2011-238
# news_english/news_english-2011-239
# news_english/news_english-2011-240
# news_english/news_english-2011-241
# news_english/news_english-2011-242
# news_english/news_english-2011-243
# news_english/news_english-2011-244
# news_english/news_english-2011-245
# news_english/news_english-2011-246
# news_english/news_english-2011-247
# news_english/news_english-2011-248
# news_english/news_english-2011-249
# news_english/news_english-2011-250
# news_english/news_english-2011-251
# news_english/news_english-2011-252
# news_english/news_english-2011-253
# news_english/news_english-2011-254
# news_english/news_english-2011-255
# news_english/news_english-2011-256
# news_english/news_english-2011-257
# news_english/news_english-2011-258
# news_english/news_english-2011-259
# news_english/news_english-2011-260
# news_english/news_english-2011-261
# news_english/news_english-2011-262
# news_english/news_english-2011-263
# news_english/news_english-2011-264
# news_english/news_english-2011-265
# news_english/news_english-2011-266
# news_english/news_english-2011-267
# news_english/news_english-2011-268
# news_english/news_english-2011-269
# news_english/news_english-2011-270
# news_english/news_english-2012-0
# news_english/news_english-2012-1
# news_english/news_english-2012-2
# news_english/news_english-2012-3
# news_english/news_english-2012-4
# news_english/news_english-2012-5
# news_english/news_english-2012-6
# news_english/news_english-2012-7
# news_english/news_english-2012-8
# news_english/news_english-2012-9
# news_english/news_english-2012-10
# news_english/news_english-2012-11
# news_english/news_english-2012-12
# news_english/news_english-2012-13
# news_english/news_english-2012-14
# news_english/news_english-2012-15
# news_english/news_english-2012-16
# news_english/news_english-2012-17
# news_english/news_english-2012-18
# news_english/news_english-2012-19
# news_english/news_english-2012-20
# news_english/news_english-2012-21
# news_english/news_english-2012-22
# news_english/news_english-2012-23
# news_english/news_english-2012-24
# news_english/news_english-2012-25
# news_english/news_english-2012-26
# news_english/news_english-2012-27
# news_english/news_english-2012-28
# news_english/news_english-2012-29

# %% [markdown]
# ### Paso 8.1 (OPCIONAL): Persistencia de las noticias (destino: local)
# Las noticias serán guardadas en el mismo directorio de este notebook como **ALL_NEWS_ENGLISH.csv**

# %%
save_local('news_english', 'ALL_NEWS_ENGLISH')

# %% [markdown]
# ### Paso 8.2 (OPCIONAL): Persistencia de las noticias (destino: nube)
# En caso de querer subir información a la nube se debe utilizar el método **upload_to_lz()**, en donde *database* es el nombre de la base de datos a la cual usted esté autorizado y *table_name* el nombre con el que la tabla quedará cargada en la nube. Tenga en cuenta que en el mismo directorio de este notebook debe existir un archivo llamado **credentials.json**, debe contener lo siguiente: **{ "user": "su_usuario", "password": "su_contraseña", "server": "sbmdeblze004" }**

# %%
save_local('news_english', 'ALL_NEWS_ENGLISH')
all_news = pd.read_csv('ALL_NEWS_ENGLISH.csv')
all_news = all_news.astype(str)

database = 'proceso'
table_name = 'dasolano_eltiempo_news_english'

upload_to_lz(dataframe = all_news, database = database, table_name = table_name)
clear_output(wait = True)
# !del ALL_NEWS_ENGLISH.csv
print(f'LAS NOTICIAS HAN SIDO CARGADAS A LA NUBE EXITOSAMENTE. UBICACIÓN LZ: {database}.{table_name}')

# %% [markdown]
# ### Paso 9: Cálculo del sentimiento en inglés (título, subtítulo y contenido)
#
# Se calcula el sentimiento del título, subtitulo y contenido de cada noticia usando las librerías [NLTK](https://www.nltk.org/), [TextBlob](https://textblob.readthedocs.io/en/dev/) y [FinBert](https://huggingface.co/yiyanghkust/finbert-tone). El resultado se guardará en un archivo (en el mismo directorio de este notebook) llamado **news_sentiment_english.csv**. Para ello, ejecute la siguiente celda

# %%
if os.path.exists('news_sentiment_english'):
  if os.listdir('news_sentiment_english'):
    # !rmdir /s /q news_sentiment_english
    # !mkdir news_sentiment_english
else:
  # !mkdir news_sentiment_english

for current_year in range(int(start_year), int(end_year) + 1):
    news_english = pd.read_csv(f'news_english/news_english-{current_year}.csv')
    news_english = news_english.astype(str)

    #NLTK

    news_english_title_nltk = news_english['news_title_english'].apply(lambda title: sia.polarity_scores(str(title)))
    news_english_subtitle_nltk = news_english['news_subtitle_english'].apply(lambda subtitle: sia.polarity_scores(str(subtitle)))
    news_english_content_nltk = news_english['news_text_content_english'].apply(lambda content: sia.polarity_scores(str(content)))

    news_english['news_title_english_polarity_POS_nltk'] = news_english_title_nltk.apply(lambda sentiment: sentiment['pos'])
    news_english['news_title_english_polarity_NEU_nltk'] = news_english_title_nltk.apply(lambda sentiment: sentiment['neu'])
    news_english['news_title_english_polarity_NEG_nltk'] = news_english_title_nltk.apply(lambda sentiment: sentiment['neg'])
    news_english['news_title_english_polarity_COM_nltk'] = news_english_title_nltk.apply(lambda sentiment: sentiment['compound'])

    news_english['news_subtitle_english_polarity_POS_nltk'] = news_english_subtitle_nltk.apply(lambda sentiment: sentiment['pos'])
    news_english['news_subtitle_english_polarity_NEU_nltk'] = news_english_subtitle_nltk.apply(lambda sentiment: sentiment['neu'])
    news_english['news_subtitle_english_polarity_NEG_nltk'] = news_english_subtitle_nltk.apply(lambda sentiment: sentiment['neg'])
    news_english['news_subtitle_english_polarity_COM_nltk'] = news_english_subtitle_nltk.apply(lambda sentiment: sentiment['compound'])

    news_english['news_text_content_english_polarity_POS_nltk'] = news_english_content_nltk.apply(lambda sentiment: sentiment['pos'])
    news_english['news_text_content_english_polarity_NEU_nltk'] = news_english_content_nltk.apply(lambda sentiment: sentiment['neu'])
    news_english['news_text_content_english_polarity_NEG_nltk'] = news_english_content_nltk.apply(lambda sentiment: sentiment['neg'])
    news_english['news_text_content_english_polarity_COM_nltk'] = news_english_content_nltk.apply(lambda sentiment: sentiment['compound'])

    #TEXTBLOB

    news_english_title_textblob = news_english['news_title_english'].apply(lambda title: TextBlob(str(title)).sentiment)
    news_english_subtitle_textblob = news_english['news_subtitle_english'].apply(lambda subtitle: TextBlob(str(subtitle)).sentiment)
    news_english_content_textblob = news_english['news_text_content_english'].apply(lambda content: TextBlob(str(content)).sentiment)

    news_english['news_title_english_pol_textblob'] = news_english_title_textblob.apply(lambda sentiment: sentiment.polarity)
    news_english['news_title_english_sub_textblob'] = news_english_title_textblob.apply(lambda sentiment: sentiment.subjectivity)

    news_english['news_subtitle_english_pol_textblob'] = news_english_subtitle_textblob.apply(lambda sentiment: sentiment.polarity)
    news_english['news_subtitle_english_sub_textblob'] = news_english_subtitle_textblob.apply(lambda sentiment: sentiment.subjectivity)

    news_english['news_text_content_english_pol_textblob'] = news_english_content_textblob.apply(lambda sentiment: sentiment.polarity)
    news_english['news_text_content_english_sub_textblob'] = news_english_content_textblob.apply(lambda sentiment: sentiment.subjectivity)

    #FINBERT

    news_english_title_textblob = news_english['news_title_english'].apply(lambda title: nlp(str(title)))
    news_english_subtitle_textblob = news_english['news_subtitle_english'].apply(lambda subtitle: nlp(str(subtitle)))

    news_english['news_title_english_label_finbert'] = news_english_title_textblob.apply(lambda sentiment: sentiment[0]['label'])
    news_english['news_title_english_label_score_finbert'] = news_english_title_textblob.apply(lambda sentiment: sentiment[0]['score'])

    news_english['news_subtitle_english_label_finbert'] = news_english_subtitle_textblob.apply(lambda sentiment: sentiment[0]['label'])
    news_english['news_subtitle_english_label_score_finbert'] = news_english_subtitle_textblob.apply(lambda sentiment: sentiment[0]['score'])

    news_english.to_csv(f'./news_sentiment_english/news_sentiment_english-{current_year}.csv', index = False)

    print(f'CALCULO DE SENTIMIENTO (INGLÉS) DE NOTICIAS DEL AÑO {current_year} REALIZADO EXITOSAMENTE')

print('*' * 80)
print('CALCULO DE SENTIMIENTO (INGLÉS) REALIZADO EXITOSAMENTE')

# %% [markdown]
# ### Paso 9.1 (OPCIONAL): Persistencia de las noticias en inglés con sentimiento (destino: local)
# Las noticias serán guardadas en el mismo directorio de este notebook como **ALL_NEWS_SENTIMENT_ENGLISH.csv**

# %%
save_local('news_sentiment_english', 'ALL_NEWS_SENTIMENT_ENGLISH')

# %% [markdown]
# ### Paso 9.2 (OPCIONAL): Persistencia de las noticias en inglés con sentimiento (destino: nube)
# En caso de querer subir información a la nube se debe utilizar el método **upload_to_lz()**, en donde *database* es el nombre de la base de datos a la cual usted esté autorizado y *table_name* el nombre con el que la tabla quedará cargada en la nube. Tenga en cuenta que en el mismo directorio de este notebook debe existir un archivo llamado **credentials.json**, debe contener lo siguiente: **{ "user": "su_usuario", "password": "su_contraseña", "server": "sbmdeblze004" }**

# %%
save_local('news_sentiment_english', 'ALL_NEWS_SENTIMENT_ENGLISH')
all_news = pd.read_csv('ALL_NEWS_SENTIMENT_ENGLISH.csv')
all_news = all_news.astype(str)

database = 'proceso'
table_name = 'dasolano_eltiempo_news_sentiment_english'

upload_to_lz(dataframe = all_news, database = database, table_name = table_name)
clear_output(wait = True)
# !del ALL_NEWS_SENTIMENT_ENGLISH.csv
print(f'LAS NOTICIAS HAN SIDO CARGADAS A LA NUBE EXITOSAMENTE. UBICACIÓN LZ: {database}.{table_name}')
